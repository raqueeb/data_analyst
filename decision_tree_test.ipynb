# %% [markdown]
# <a href="https://colab.research.google.com/github/raqueeb/data_analyst/blob/main/decision_tree_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ডিসিশন ট্রি হাতেকলমে দেখা
#
# ### লাইব্রেরি ইম্পোর্ট করছি

# %%
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree

# %% [markdown]
# ### ডাটাকে তৈরি করছি

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# ### ক্লাসিফায়ারকে ফিট করছি ডিফল্ট হাইপার প্যারামিটার দিয়ে

# %%
clf = DecisionTreeClassifier(random_state=1234)
model = clf.fit(X, y)

# %% [markdown]
# ### ডিসিশন ট্রি প্লট করে দেখা

# %%
import graphviz

dot_data = tree.export_graphviz(clf, out_file=None, 
                                feature_names=iris.feature_names,  
                                class_names=iris.target_names,
                                filled=True)

# %% [markdown]
# ### গ্রাফ আঁকি

# %%
graph = graphviz.Source(dot_data, format="png") 
graph

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=iris.feature_names,  
                      class_names=iris.target_names,  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# ### ডিসিশন ট্রি একদম ভেতর থেকে দেখা

# %%
# !pip install dtreeviz

# %%
import warnings
warnings.filterwarnings('ignore')

from dtreeviz.trees import dtreeviz 

viz = dtreeviz(clf, X, y,
                target_name="target",
                feature_names=iris.feature_names,
                class_names=list(iris.target_names))
viz
